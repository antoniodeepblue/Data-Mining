# %% [markdown]
# <a href="https://colab.research.google.com/github/antoniodeepblue/Data-Mining/blob/main/Presentaci%C3%B3n_del_proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📒 Presentación del proyecto

# %% [markdown]
# **📒 Presentación del proyecto**
#
#
# Se pretende hacer un análisis sobre un conjunto de datos que se refiere a los clientes de un distribuidor mayorista. Incluye el gasto anual en unidades monetarias (m.u.) en diversas categorías de productos. Con el conjunto de datos se pueden utilizar varios algoritmos de agrupación en clústeres.
#
#
# Las fases del proceso de extracción de conocimiento
#
# 1. Definición de la tarea de minería de datos
#
# 2. Selección de datos
#
# 3. Preparación de datos
#
# 4. Minería de datos
#
# 5. Evaluación e interpretación del modelo
#
# 6. Integración
#
# Este proceso no es lineal, sino que se realimenta y continúa: nuevos cambios en la situación pueden hacer que nuestro conocimiento deje de ser correcto, por lo que será preciso volver a extraer conocimiento nuevo.
#
# A continuación, se describe brevemente en que consistirían las seis fases principales para llevar a cabo el proyecto de minería de datos:

# %% [markdown]
# **🎓 1. Definición de la tarea de minería de datos**
#
#
# En esta primera fase se tratará de determinar el objetivo del proceso de minería de datos. La tarea principal de cada uno de estos proyectos en general puede asimilarse a alguna de las siguientes:
#
# 1. Encontrar similitudes y agrupar objetos parecidos.
#
# 2. Clasificar objetos.
#
# 3. Predecir.
#
# 4. Describir.
#
# 5. Explicar.
#
# En el ejemplo de este ejercicio, el objetivo sería construir un modelo o regla general que nos permita clasificar todos los objetos.
#
# 1. Encontrar similitudes y agrupar objetos parecidos. Los modelos típicos para alcanzar estos objetivos son los modelos de agregación (clustering) procedentes del análisis de datos o del aprendizaje automático y los modelos asociativos. Para encontrar similitudes consiste en encontrar grupos de clientes parecidos.
#
# 2. Clasificar objetos. Aquí lo más habitual es partir de una situación más informada, sabiendo que existen grupos ya definidos. Lo que nos interesa en este caso es estudiar mejor las diferencias existentes entre un grupo y otro, sus características peculiares. Por norma general, la clasificación de objetos es el paso previo a la realización de predicciones; es decir, para saber alguna conducta de interés a partir de una serie de datos. (En este caso no aplicamos).
#
# 3. Predecir. Se trata de obtener conocimiento que nos permita predecir aquello que nos interese. En una clasificación binaria de dos clases posibles, se trata de predecir el valor de la clase dentro de un conjunto limitado de valores (normalmente entre [0, 1]). En otros casos con más clases, la clasificación puede entenderse como un proceso de predicción que tiene que indicar el valor de esta etiqueta. (En este caso no aplicamos).
#
# 4. Describir. Con conocimiento descriptivo nos solemos referir a encontrar y expresar asociaciones significativas o causales entre diferentes variables.
#
# 5. Explicar. Aquí se trata de obtener modelos que puedan darnos las razones de por qué se ha producido un comportamiento determinado. Utilizaremos el algoritmo K-means para encontrar patrones a partir de la identificación de grupos similares. Es un algoritmo de clasificación no supervisada.
#
# Por lo tanto, a la hora de definir la tarea de minería de datos:
#
# • Aproximar el objetivo a alguna de las tareas genéricas que hemos mencionado. Este punto es el más crítico, y para el que resulta más difícil dar reglas de aplicabilidad general. Decidir, por ejemplo, que tenemos que conocer mejor a nuestros clientes es un objetivo demasiado general que necesita ser precisado. Tenemos datos de clientes mayoristas: ¿Queremos determinar las características distintivas de grupos separados geográficamente o por canal de compra del cliente? Entonces tenemos que clasificar. Sin embargo, sea como sea, siempre quedan objetivos que requieren un esfuerzo combinado. Quizá primero tendremos que agrupar, después clasificar y más tarde extraer un modelo predictivo.
#
# • Decidir el modelo que necesitamos. Este punto nos obliga a conocer bien los distintos modelos que existen, para qué sirven y para qué no. Podemos compararlos, por ejemplo, en términos de su capacidad expresiva, de su comprensibilidad, de su facilidad de implementación e integración en el sistema de información de la empresa.
#
# • Seleccionar el método necesario para construirlo. Este tercer punto está muy relacionado con el segundo y nos permitirá evaluar las posibilidades y las características de las distintas herramientas existentes: complejidad del método y coste computacional.
#
# Además, debemos decidir el entorno donde tiene que desarrollarse el proyecto para la implementación de los resultados: En este caso lo haremos en Colaboratory en el entorno Python.

# %% [markdown]
# **🎓 2. Selección de datos**
#
#
# La tecnología de data warehousing está especialmente orientada a facilitar la localización de los datos dentro de una empresa en relación con varios tipos de utilidades. Un data warehouse integra datos procedentes de los distintos datos de cada departamento de una empresa.
#
# Hay que localizar las fuentes de datos a partir de:
#
# • Las bases de datos dispersas por los distintos departamentos que consideramos que pueden ser relevantes para el proyecto que llevamos a cabo.
#
# • Las bases de datos transaccionales, que registran las operaciones día a día y que acumulan información histórica que puede ser relevante para obtener el modelo que estamos buscando.
#
# Para nuestro caso, que no depende de ninguna empresa, sino un ejemplo de un repositorio para el estudio y análisis.
#
# Se ha seleccionado un conjunto de datos de la página web:
#
# https://cml.ics.uci.edu/home/about-us/
#
# que tiene variedad de repositorios de aprendizaje automático:
#
# **Centro de Aprendizaje Automático y Sistemas Inteligentes** de UC Irvine. Los proyectos de investigación en el Centro utilizan teorías y técnicas de la intersección de la informática, la estadística y las matemáticas, incluidas las ideas fundamentales de algoritmos, estructuras de datos, inteligencia artificial y bases de datos (informática), análisis de datos multivariantes, estimación bayesiana y estadística computacional (de estadísticas) y teoría de optimización y probabilidad (de matemáticas). La investigación en el Centro también tiene un componente interdisciplinario muy fuerte, que incluye colaboraciones en áreas que van desde sensores y computación ubicua, hasta bases de datos y visión por computadora, ingeniería de software y aplicaciones web.
#
# En particular se ha seleccionado el repositorio: UCI Machine Learning Repository: Wholesale customers Data Set.
#
# http://archive.ics.uci.edu/ml/datasets/wholesale+customers
#
# Tenemos un archivo csv, que tiene todas las columnas (datos) de entrada en el archivo.

# %% [markdown]
# **🎓 3.1. Preparación de los datos**
#
#
# Esta fase, aunque parezca sencilla, junto con la de selección de datos, consume el 70 % del esfuerzo (¡o más!) en los proyectos de minería de datos de nueva implantación. En esta fase se utilizarán técnicas para asegurar la limpieza de los datos, la transformación de los datos y la reducción de la dimensionalidad.
#
# Tendremos que verificar distintos aspectos de los datos:
#
# 1) Que los datos tengan la calidad suficiente. Asegurarse de la calidad del modelo resultante (por ejemplo, que asegure que será lo suficientemente predictivo, si se trata de crear un modelo de este tipo).
#
# 2) Que los datos sean los necesarios. Puede ser necesario añadir nuevos datos, obtener de nuevos o combinar algunos de ellos.
#
# 3) Que estén en la forma adecuada. La más típica es que los datos sean valores numéricos continuos y los métodos solo admitan valores discretos. Una práctica común es generar nuevas variables derivadas de expresiones más o menos complejas a partir de los datos originales. Esto permite originar indicadores que en sí mismos ya agregarán información y serán muy útiles en el proceso de conocer la información que guardan los datos y en el posterior proceso de creación del modelo.
#
#
#
# **Análisis exploratorio**
#
# Queremos hacer una primera aproximación al conjunto de datos escogido y responder a las preguntas más básicas: ¿Cuánto registros tiene? ¿Cuántas variables? ¿De qué tipología son? ¿Cómo se distribuyen los valores de las variables? ¿Hay problemas con los datos, por ejemplo, campos vacíos? ¿Puedo intuir ya el valor analítico de los datos? ¿Qué primeras conclusiones puedo extraer?
#
# El primer paso para realizar un análisis exploratorio es cargar el fichero de datos.
#
# In []:
#
# from google.colab import drive
#
# drive.mount('/content/drive')
#
# Mounted at /content/drive
#
# In []:
#
# import numpy as np
#
# import pandas as pd
#
# import seaborn as sns
#
# import matplotlib.pyplot as plt
#
# In []:
#
# //lee el fichero .csv y lo devuelve como DataFrame
#
# data = pd.read_csv('/content/drive/MyDrive/Ventas_clientes.csv')
#
# data.head(10)
#
# Out[]:
#
# ![image.png](data:image/png;base64,...)
#
#
#
# **Exploración del conjunto de datos**
#
# Verificamos la estructura del juego de datos principal. Vemos el número de columnas que tenemos y ejemplos de los contenidos de las filas.
#
# Con la info ya vemos que tiene 440 entradas y todas son no nulas
#
# In []:
#
# data.info()
#
# ![image.png](data:image/png;base64,...)
#
# Vemos que tenemos 8 variables y 440 registros Revisamos la descripción de las variables contenidas en el fichero y si los tipos de variables se corresponden con las que hemos cargado. Las organizamos lógicamente para darles sentido y construimos un pequeño diccionario de datos utilizando la documentación auxiliar.
#
#
#
# **Información de atributos**
#
# • Hechos a estudiar:
#
# 1) FRESCO: gasto anual (m.u./unidades monetarias) en productos frescos.
#
# 2) LECHE: gasto anual (m.u.) en productos lácteos.
#
# 3) GROCERY: gasto anual (m.u.) en productos comestibles.
#
# 4) FROZEN: gasto anual (m.u.) en productos congelados.
#
# 5) DETERGENTS_PAPER: gasto anual (m.u.) en detergentes y productos de papel.
#
# 6) DELICATESSEN: gasto anual (m.u.) en productos selectos y delicatessen.
#
# • Dimensión de ventas:
#
# 7) CANAL: Canal de clientes (Hotel/Restaurante/Cafetería) o Canal Minorista.
#
# • Dimensión geográfica:
#
# 8) REGIÓN: clientes Región = Lisboa, Oporto u otro.
#
# • Estadística Descriptiva:
#
# Se observan varias características: cantidad, promedio, desviación estándar, valor mínimo, valor máximo, cuartiles. Por ejemplo: se observa que el producto que más se vende son los frescos, con un valor promedio de 12.000. Se observa que el producto que menos se vende son los Delicatessen con un promedio de 1.524.
#
# In []:
#
# data.describe()
#
# Out[]:
#
# ![image.png](data:image/png;base64,...)
#
#
#
# **Preprocesamiento y gestión de características**
#
# Limpieza de los datos
#
# El siguiente paso será la limpieza de datos, mirando si hay valores vacíos o nulos.
#
# La limpieza de datos consiste en procesar los datos para eliminar los que sean erróneos o redundantes. También hay quien incluye en esta fase el paso consistente en eliminar algunos de los atributos de los datos, lo que se conoce como selección de atributos, y cuya intención es asegurar que con menos datos se puedan obtener modelos de la misma calidad.
#
# Aun estando en la forma adecuada, suele suceder que los datos no son perfectos al 100 %:
#
# 1) Datos incompletos. Missing values. Normalmente, lo que se hace es «completar» los valores que no aparecen. Por ejemplo, para los valores numéricos se complementa calculando el valor medio observado para un atributo, aunque también es posible usar técnicas de imputación más sofisticadas.
#
# 2) Datos redundantes. A veces se repiten tuplas que corresponden al mismo objeto.
#
# 3) Datos incorrectos o inconsistentes. Caso muy común cuando el tipo de valores que puede recibir un atributo no está controlado porque ha sido declarado como «texto libre».
#
# 4) Errores de transcripción.
#
# 5) Datos envejecidos.
#
# 6) Variaciones en las referencias a los mismos conceptos.
#
# 7) Datos sesgados. Este tipo de problema puede darse con datos que cumplen todos los otros requisitos de calidad mencionados hasta el momento. Se trata de aquellos tipos de datos que, en conjunto, reflejan preferentemente un valor determinado o conjunto de valores o que proceden de un conjunto de objetos muy determinado.
#
# In []:
#
# // Hacemos un recorrido por todas las columnas para ver el porcentaje de valores vacios
#
# for c in data.columns:
#
#   print(f"-{c} has {round(data[c].isna().sum()*100/len(data), 2)} % Valores vacios.")
#
# ![image.png](data:image/png;base64,...)
#
# Para ver si hay duplicados, y me da 0:
#
# In []:
#
# // No se tienen filas duplicadas
#
# data.duplicated().sum()
#
# Out[]:
#
# 0
#
# Vemos que no hay valores nulos en los datos. También verificamos que no existen campos llenos de espacios en blanco ni filas duplicadas.

# %% [markdown]
# **🎓 3.2. Transformación de los datos**
#
#
# 1) Datos numéricos a categóricos. La solución consiste en asignar una categoría a cada rango de valores que necesitemos, fijando bien una correspondencia entre los valores numéricos y la categoría o bien intercediendo automáticamente procedimientos de discretización.
#
# 2) Datos categóricos a numéricos. Disponemos de datos que aparecen descritos mediante valores categóricos, y lo que necesitamos realmente es disponer de los valores numéricos correspondientes.
#
# Todas las variables son integer, pero Channel y Region a pesar de ser integer, son categóricas. Se detecta bajo los datos que son ofrece el Dataset (la página donde he descargado el repositorio) y observando la descripción de cada variable.
#
# Ya que Channel, es el canal de los clientes que puede ser 1 o 2 (categórica):
#
# 1 = Hotel/Restaurante/Cafetería.
#
# 2 = Venta al por menor.
#
# Ya que Region, es categórica (1 , 2 o 3)
#
# 1 = LISBOA
#
# 2 = OPORTO
#
# 3 = OTRA REGION
#
# Separamos el dataSet entre categóricas y numéricas.
#
# In []:
#
# cols_categoricas = ['Channel', 'Region']
#
# // dataframe con las variables categóricas
#
# df_categoricas = data[cols_categoricas]
#
# // dataframe con las variables numéricas
#
# df_numericas = data.drop(columns=cols_categoricas)
#
# 3) Otras transformaciones. De escala, o de unidades, por lo general:
#
# a) Simplificación de valores.
#
# b) Agrupación de valores continuos en franjas.
#
# c) Normalización de datos: poner los valores numéricos en un intervalo determinado. Por ejemplo, muchas redes neuronales y algoritmos de agrupación obligan (o prefieren) a que los valores numéricos estén entre 0.0 y 1.0.
#
# d) Adición de una etiqueta que indique a qué clase pertenece un registro.
#
# e) Expansión de un atributo. El valor de un atributo puede adoptar valores en un conjunto limitado de categorías. En inglés, esto es lo que se conoce como dummy variables.
#
# In []:
#
# // Transformar las variables categóricas en númericas
#
# from sklearn.preprocessing import OneHotEncoder
#
# enc = OneHotEncoder()
#
# // hacer OneHotEncoder por cada columna categórica
#
# for col in cols_categoricas:
#
#   // transformar la columna aplicando el OneHotEncoder
#
#   transformed = enc.fit_transform(df_categoricas[col].to_numpy().reshape(-1, 1))
#
#   // crear los nombres de las nuevas columnas a partir del nombre de la columna original (col)
#
#   column_names = [col + str(i+1) for i in range(len(df_categoricas[col].value_counts()))]
#
#   // convertir a Dataframe
#
#   enc_data = pd.DataFrame(transformed.toarray(), columns=column_names)
#
#   // agregar las nuevas columnas codificadas al datset numérico
#
#   df_numericas = df_numericas.join(enc_data)
#
# Como channel tiene 2 valores, pues obtenemos 2 variables. Como REgion tiene 3 valores, obtenemos 3 variables.
#
# In []:
#
# // Nos fijamos que en la transformacion, de cada variable que se creo numerica,
#
# // por ejemplo Channel1, para cada ejemplo será 1 si pertenece 0 = si no pertenece.
#
# df_numericas.head()
#
# Out[]:
#
# ![image.png](data:image/png;base64,...)
#
#
# In []:
#
# // Normalizar los datos, y se lo asignamos a la variable X (la matriz sobre la que vamos a trabajar)
#
# from sklearn.preprocessing import StandardScaler
#
# scaler = StandardScaler()
#
# X = scaler.fit_transform(df_numericas.values)
#
# No todas estas transformaciones pueden hacerse utilizando el lenguaje de consulta y manipulación de bases de datos del que se disponga.
#
# Las fuentes de datos pueden reunir información sobre un cierto conjunto de atributos, y puede que lo que necesitemos sea un conjunto diferente. Los problemas más habituales:
#
# i. Derivación de datos.
#
# ii. Fusión de datos o enriquecimiento.
#
# Reducción de la dimensionalidad
#
# A partir de ciertos niveles de registros y atributos, la eficiencia de los algoritmos de minería de datos empieza a reducirse. Es la llamada maldición de la dimensionalidad. Por lo tanto, si es posible trabajar con menos datos y obtener los mismos resultados, sería mejor desde un punto de vista de eficiencia.
#
# Los métodos de reducción de dimensionalidad buscan justamente trabajar con menos datos y obtener los mismos resultados. Las técnicas habituales de reducción de la dimensionalidad.
#
# 1) Reducción del número de registros por tratar. Consiste en encontrar un conjunto de datos de menores dimensiones para construir el tipo de modelo que necesitamos con el nivel de calidad necesario.
#
# La estadística ha desarrollado herramientas para elegir conjuntos suficientes de datos de cara a la construcción de modelos. Los problemas que tenemos que evitar aquí son principalmente que el conjunto elegido no sea demasiado sesgado hacia un conjunto de objetos con características muy concretas y poco representativa. Si el conjunto es demasiado reducido, las conclusiones que se extraerán del modelo resultante final no serán lo suficientemente significativas. Por lo tanto, en algunas ocasiones es necesario conservar un conjunto alto de registros para mantener la calidad suficiente.
#
# Las muestras de datos en estadística y en minería de datos es que, mientras que en la primera los casos extremos (outliers) se descartan sistemáticamente, en la segunda pueden ser los que más interesan.
#
# Sobre el dataframe con las variables numéricas (tengo 6 variable numéricas), que vamos a representar con un diagrama de cajas, para ver si distribución en cuanto a que valores ronda y si tiene valores atípicos(outliers)
#
# In []:
#
# nfilas = 2
#
# ncols = 3
#
# fig, ax = plt.subplots(nfilas, ncols, figsize=(15, 10))
#
# // wspace - para controlar el espacio horizontal entre subplots
#
# // hspace - para controlar el espaccio vertical entre subplots
#
# plt.subplots_adjust(wspace=0.5, hspace=0.5)
#
# for i in range(nfilas):
#
#   for j in range(ncols):
#
#     indice_col = ncols*i+j
#
#     sns.boxplot(data=df_numericas.iloc[:, indice_col], ax=ax[i,j])
#
#     ax[i,j].set_xlabel(df_numericas.columns[indice_col])
#
#     ax[i,j].set_xticklabels([])
#
# plt.show()
#
# ![image.png](data:image/png;base64,...)
#
# Analizando los diagramas de Cajas al detalle, sobre todo para identificar los outliers:
#
# Fresh: Los outliers están bastante alejados tanto de la mediana como de la concentración de datos (causan ruido de 60.000 hacia arriba, debemos analizarlos, pero pueden ser clientes que hacen compras muy grandes)
#
# Milk: Los outliers están bastante alejados tanto de la mediana como de la concentración de datos (causan ruido de 30.000 hacia arriba, debemos analizarlos, pero pueden ser clientes que hacen compras muy grandes)
#
# Grocery: Los outliers están bastante alejados tanto de la mediana como de la concentración de datos (causan ruido de 40.000 hacia arriba, debemos analizarlos, pero pueden ser clientes que hacen compras muy grandes)
#
# Frozen: Los outliers están bastante alejados tanto de la mediana como de la concentración de datos. Vemos que se acercan la mayoría de los datos al cero. (causan ruido de 20.000 hacia arriba, debemos analizarlos, pero pueden ser clientes que hacen compras muy grandes)
#
# Detergents_Paper: Los outliers están bastante alejados tanto de la mediana como de la concentración de datos. Vemos que se acercan la mayoría de los datos al cero. (causan ruido de 20.000 hacia arriba, debemos analizarlos, pero pueden ser clientes que hacen compras muy grandes)
#
# Delicasse: Los outaliers están bastante alejados tanto de la mediana como de la concentración de datos. Vemos que se acercan la mayoría de los datos al cero. (causan ruido de 10.000 hacia arriba, debemos analizarlos, pero pueden ser clientes que hacen compras muy grandes)
#
# Conclusión: Los valores atípicos que representan estos diagramas de Cajas, demuestra que tiene valores atípicos de compras grandes de clientes potenciales, pero que no son errores. No existe ningún valor por debajo de cero, es evidente pues no pueden existen compras negativas. De acuerdo el conjunto de datos, los outliers son clientes premium (mayoristas) y no debemos eliminar esa información. Es complicado decir que existen errores porque no sabemos cuántos mayoristas tenemos, entonces será complicado que el algoritmo sea muy exacto. También podemos estandarizar los datos atípicos. O por ejemplo hacer una media teniendo en cuento la densidad de la población. También podemos ver el rango en el que se mueven las ventas.
#
# Contabilizamos los valores atípicos, por ejemplo, de Fresh y salen 19 outliers y gran porcentaje con respecto a las 440 ejemplos que tenemos. Es cierto que el algoritmo no va a ser muy exacto, ya que tiene muchos datos outliers
#
# In []:
#
# // Ejemplo de análisis de un outlier relacionado con la variable Fresh
#
# // 19 valores por encima de 39000
#
# len(df_numericas[df_numericas['Fresh'] > 39000])
#
# Out[]:
#
# 19
#
# A priori no hay que eliminar ningún dato.
#
# 2) Reducción del número de atributos por tratar. La reducción del número de atributos por tratar también recibe el nombre de selección de atributos. Se deben detectar atributos irrelevantes que carecen de efecto alguno sobre la calidad del modelo final y atributos o combinaciones de atributos equivalentes.
#
# A priori no hay que eliminar ningún atributo.
#
# Para nuestro modelo de clustering se puede visualizar la correlación entre pares de variables. Las herramientas de visualización son bastante útiles en la fase de preparación de datos y la interpretación de los modelos resultantes.
#
# In [ ]:
#
# //Visualizamos el diagrama de dispersion solo con las numericas
#
# sns.pairplot(df_numericas)
#
# Out[ ]:
#
# <seaborn.axisgrid.PairGrid at 0x7efc209bdeb0>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **🎓 4. Minería de datos**
#
#
# Existen diversos modelos que podemos elegir de acuerdo al objetivo que tengamos. Utilizaremos algoritmos de clasificación, predicción, regresión lineal, clustering (ejemplo k-means o k-nearest neighbor), Deep Learning (ej.: red neuronal), bayesiano, etc. y podrá haber variantes si lo que vamos a procesar son imágenes, sonido, texto, valores numéricos.
#
# Tenemos decidido qué tipo de modelo queremos obtener. Por lo tanto, ahora hay que elegir un método de construcción de modelos entre la multitud de métodos que permiten obtener el tipo de modelo que nos interesa.
#
# El proceso de construcción de modelos consiste en encontrar el modelo (el conocimiento) que responde mejor a las características implícitas en los datos. Este tipo de problema suele conceptualizarse como un proceso de búsqueda. Los principales problemas de este tipo de conceptualización son los siguientes:
#
# 1) Disponer de una medida de calidad que califica como el mejor posible un modelo que solo es relativamente bueno con respecto a los modelos que tiene cerca de él, pero que no es el modelo óptimo dentro de todo el espacio de soluciones posibles. Este problema se denomina problema de la obtención de mínimos locales.
#
# 2) Obtener un modelo que sea bueno teniendo en cuenta solo los datos de los que disponemos. Este problema que consiste en obtener modelos que generalizan mal y son demasiado específicos con respecto a los datos que han visto se conoce como el problema de la sobreespecialización (en inglés, overfitting).
#
# 3) En el transcurso del tiempo es posible que el modelo obtenido se degenere porque empiezan a aparecer observaciones nuevas para las que no generaliza bien. Este es el problema del envejecimiento de modelos. Es necesario actualizarlos, ya sea desde cero o incrementalmente, dependiendo del tipo de modelo del que se trate.
#
# Podemos dividir los métodos de minería de datos en lo que concierne a:
#
# a) Conocimiento a priori. Reutilización del conocimiento extraído por otro sistema de minería de datos con el fin de guiar el proceso de búsqueda. En inglés, multistrategy learning.
#
# b) Al tipo de datos.
#
# 1.   Métodos que utilizan solo observaciones, es decir, solo información con
# respecto a los valores que se han recogido, sin más información añadida. Los métodos que parten de esta base se conocen como métodos no supervisados. Un ejemplo típico de ello son los métodos de agregación. En inglés, clustering.
#
# 2.   Métodos que añaden información discriminando las observaciones. Los métodos que parten de esta situación inicial se denominan métodos supervisados. Un ejemplo típico de ello es la clasificación.
#
# c) Al proceso de construcción:
#
# 1. Métodos batch.
#
# 2. Métodos incrementales.
#
# 3. Métodos interactivos.
#
# En nuestro ejemplo de clientes mayoristas estábamos buscando un método que parte de la base que utiliza solo observaciones, entonces es un método no supervisado. Un ejemplo típico de ello son los métodos de agregación. En inglés, clustering. Utilizaremos un algoritmo particional como k-means.
#
# Por ejemplo, si queremos calcular para cada k, en este caso tenemos 11 clúster que pueden ser hasta un máximo de 11 que son las variables que tenemos. Entonces hemos aplicado K-means para calcular el k optimo, que lo deducimos a través del cuadrado de las distancias y de las siluetas.
#
# In []:
#
# from sklearn.cluster import KMeans
#
# from sklearn.metrics import silhouette_score
#
# In []:
#
# // en n guardo la cantidad de variables
#
# n = len(df_numericas.columns)
#
# n
# Out[]:
#
# 11
#
# In []:
#
# suma_cuadrados = []
#
# coeff_silueta = []
#
# for k in range(1, n+1):
#
#   km = KMeans(n_clusters=k, n_init='auto').fit(X)
#
#   // Agregar la suma de los cuadrados de las distancias de cada ejemplo
#
#   // a su centroide más cercano
#
#   suma_cuadrados.append(km.inertia_)
#
#   if k > 1:
#
#     coeff_silueta.append(silhouette_score(X, km.labels_))
#
# In []:
#
# x = list(range(1, n+1))
#
# plt.plot(x, suma_cuadrados, 'bo-')
#
# plt.xlabel('Cantidad de clases')
#
# plt.ylabel('Suma de los cuadrados de las distancias')
#
# plt.xticks(x)
#
# plt.title("Graficado del cuadrado de las distancias")
#
# plt.show()
#
# ![image.png](data:image/png;base64,...)
#
# Observando el gráfico de siluetas que da el nivel de solapamiento entre grupos, y con 7 grupos está bastante bien. Analizando el grafico de siluetas y el de la suma de las cuadrados de las distancias, el resultado sería con k = 7 clusters.
#
# Los outliers suelen influir bastante en el graficado del COEFICIENTE DE SILUETAS, porque mide el nivel de solapamiento entre 2 grupos distintos y nos dará una representación compleja.
#
# In []:
#
# // EN ESTE CASO ES N-1 PORQUE TIENEQUE SER COMO MINIMO HAY QUE EMPEZAR CON 2 GRUPOS.
#
# plt.plot(x[1:], coeff_silueta, 'bo-')
#
# plt.xlabel('Cantidad de clases')
#
# plt.ylabel('Coeficiente de silueta')
#
# plt.xticks(x[1:])
#
# plt.title("Graficado de SILUETAS")
#
# plt.show()
#
#
# ![image.png](data:image/png;base64,...)
#
# El algoritmo K-means es un método de agrupamiento que se utiliza para dividir un conjunto de datos en K grupos (o "clusters") basados en características similares. El proceso de entrenamiento del modelo K-means consta de los siguientes pasos:
#
# 1. Inicialización de centroides: Se eligen K puntos aleatorios del conjunto de datos como los centroides iniciales. Un centroide es simplemente un punto que representa el centro de un grupo.
#
# 2. Asignación de puntos a clusters: Cada punto de datos es asignado al cluster cuyo centroide es el más cercano en términos de distancia euclidiana u otra métrica de distancia específica.
#
# 3. Actualización de centroides: Una vez que todos los puntos han sido asignados a clusters, los centroides se recalculan tomando el promedio de todos los puntos asignados a ese cluster. Esto significa que el centroide se mueve hacia el centro de masas de los puntos asignados.
#
# 4. Repetición de pasos 2 y 3: Los pasos 2 y 3 se repiten hasta que se cumple un criterio de parada, como un número máximo de iteraciones o una convergencia suficiente.
#
# 5. Convergencia: El algoritmo eventualmente converge a una solución donde los centroides ya no cambian entre iteraciones, lo que indica que se ha alcanzado un estado estable.
#
# 6. Resultado final: Una vez que el algoritmo ha convergido, se tienen los clusters finales y los centroides asociados.
#
# Es importante tener en cuenta que el número de clusters, K, debe ser especificado antes de iniciar el algoritmo. La elección de K es una decisión crucial y puede requerir métodos como el codo (elbow method) o el análisis de silueta para determinar el valor óptimo.
#
# El proceso de entrenamiento es relativamente rápido, pero el resultado final puede depender de la inicialización aleatoria de los centroides. Por esta razón, a veces se ejecuta el algoritmo varias veces con diferentes inicializaciones y se selecciona el mejor resultado.
#
# In []:
#
# // el número de clases elegido 7
#
# km = KMeans(n_clusters=7, n_init='auto').fit(X)
#
# df_numericas['CLASE'] = km.labels_
#
# df_numericas
#
# Out[]:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **🎓 5. Evaluación  del modelo**
#
# Típicamente, para algoritmos supervisados, el proceso de evaluación consiste en disponer de dos conjuntos de datos procedentes del mismo conjunto inicial (y ya preparado): un conjunto de datos que se utiliza para construir el modelo y otro, para evaluarlo. En algunas ocasiones, se introduce un tercer conjunto entre estos dos: el conjunto de validación. Utilizamos un conjunto de datos para construir el modelo; otro, para darlo por bueno (validarlo), y un tercero, para evaluarlo. (No es nuestro caso)
#
# No se pueden comparar modelos predictivos con modelos descriptivos. Para los modelos predictivos se buscará determinar hasta qué punto son buenos haciendo predicciones, mientras que para los modelos descriptivos evaluaremos hasta qué punto se ajustan al dominio descrito.
#
# Cuando ya tenemos un modelo que posee el nivel de calidad requerido y que ha sido validado mediante el proceso de evaluación, hay que interpretarlo y extraer el significado del conocimiento que nos está mostrando. En nuestro caso es un modelo descriptivo en el que utilizamos el algoritmo no supervisado, por ejemplo, k-means.
#
# Para evaluar un modelo K-means, puedes usar varias métricas y técnicas. Aquí te proporciono algunas de las más comunes:
#
# 1. Inercia o Suma de Cuadrados Dentro del Grupo (WCSS - Within-Cluster Sum of Squares): Esta métrica mide la dispersión de los puntos dentro de cada cluster. Es el objetivo de optimización del algoritmo K-means. Cuanto menor sea la inercia, mejor será el modelo.
#
# 2. Método del Codo (Elbow Method): Este método te permite visualmente identificar un buen número de clusters. Grafica el valor de la inercia en función del número de clusters y busca el punto donde la disminución en la inercia comienza a disminuir de manera menos pronunciada, formando un "codo". Este número de clusters es una buena elección.
#
# 3. Índice de Silueta (Silhouette Score): Esta métrica cuantifica qué tan cerca están los puntos de un cluster de los puntos de los clusters vecinos. Un valor alto indica que los puntos están bien agrupados y están lejos de los otros clusters. Es una medida de cohesión y separación entre clusters. Un valor entre -1 y 1, donde valores más cercanos a 1 son mejores.
#
# 4. Distribución de Tamaños de Cluster: Es importante entender si los clusters tienen tamaños similares o si algunos clusters son mucho más grandes que otros. Puedes visualizar la distribución de tamaños de cluster para entender mejor la calidad de la agrupación.
#
# 5. Validación Externa (si tienes etiquetas verdaderas): Si tienes etiquetas verdaderas para tus datos, puedes usar métricas como el Índice de Rand Ajustado (Adjusted Rand Index) o el Índice de Jaccard para comparar las etiquetas reales con las asignaciones de clusters.
#
# 6. Visualización de Clusters: Puedes visualizar los clusters en un espacio de baja dimensión (por ejemplo, usando PCA o t-SNE) para entender si los clusters formados tienen sentido intuitivo y se alinean con la estructura de los datos.
#
# Recuerda que no hay una única métrica que sea definitiva en todos los casos. Es importante utilizar múltiples métricas y técnicas de evaluación para tener una comprensión completa del rendimiento del modelo K-means. Además, es posible que algunas métricas sean más apropiadas dependiendo del contexto específico de tu problema y de los datos con los que estés trabajando.
#
#
#
# Analizando el gráfico de siluetas y el de la suma de las cuadrados de las distancias, el resultado sería con k = 7 clusters, es lo que se determino anteriormente, pero para el despliegue del modelo vamos a utilizar k = 4 clusters, a modo didáctico.

# %% [markdown]
# **🎓 6. Integración del modelo**
#
#
# El último paso consiste en integrar los resultados de la minería de datos en el proceso típico del sistema de información en el que esté aplicándose.
#
# No todos los modelos pueden integrarse con facilidad. La mayoría de ellos requieren una transformación al código de programación correspondiente. Buena parte de los sistemas comerciales de minería de datos ofrecen la posibilidad de traducir el modelo obtenido en procedimientos al lenguaje de programación correspondiente e insertarlo después dentro de un tratamiento de información más general.
#
# Nos tenemos que asegurar que el modelo podrá cumplir con un grado de calidad y que podrá ser mantenibles independientemente de la infraestructura que se escoja. En la actualidad podemos desplegar modelos de Minería de Datos, Machine Learning o Deep Learning en la nube, on premise, o incluso hasta en microcontroladores y minicomputadores, aunque para el entrenamiento de dichos modelos si será necesario realizarse en equipos con un cierto perfil o características. En este caso utilizamos para el despliegue del modelo: Hugging Face.
#
# En el despliegue del modelo vamos a utilizar k = 4 clusters, a modo didáctico.
#
#
#
# **Despliegue de Modelos: Hugging Face**
#
# from sklearn.cluster import KMeans
#
# In []:
#
# // el número de clases elegido 4 clusteres
#
# kmprueba = KMeans(n_clusters=4, n_init='auto').fit(X)
#
# kmprueba
#
# Out[]:
#
# ![image.png](data:image/png;base64,...)
#
#
#
# Guardar el modelo:
#
# In []:
#
# import pickle
#
# // Creamos el fichero del modelo, donde se va guardar el modelo
#
# fichero = open('prueba.pkl','wb')
#
# // Guardar el modelo
#
# pickle.dump(kmprueba, fichero)
#
# print(fichero)
#
# fichero.close()
#
# <_io.BufferedWriter name='prueba.pkl'>
#
#
# In []:
#
# // Se abre fichero para lectura
#
# fichero2 = open('prueba.pkl','rb')
#
# // Cargamos los datos del fichero
#
# lista_fichero = pickle.load(fichero2)
#
# print(lista_fichero)
#
# fichero.close()
#
# KMeans(n_clusters=4, n_init='auto')
#
#
#
# En el archivo prueba.pkl esta nuestro modelo k-means y lo guardamos en el archivo kmprueba. Posteriormente instalamos gradio.
#
# In []:
#
# !pip install gradio
#
# ![image.png](data:image/png;base64,...)
#
#
# In []:
#
# import gradio as gr
#
#
# In []:
#
# // Etiquetas de cada una de las filas
#
# kmprueba.labels_
#
# Out[]:
#
# ![image.png](data:image/png;base64,...)
#
#
#
# In []:
#
# df_numericas['CLASE'] = kmprueba.labels_
#
# df_numericas
#
#
# Out[]:
#
# ![image.png](data:image/png;base64,...)
#
#
#
# In []:
#
# import gradio as gr
#
# import numpy as np
#
# from sklearn.neighbors import KNeighborsClassifier
#
#
#
# def modelo(Fresk, Milk, Grocery, Frozen, Detergents_Paper,Delicassen,Channel1,Channel2,Region1,Region2,Region3):
#
#     species = ['0', '1', '2','3']
#
#     i = kmprueba.predict([[Fresk, Milk, Grocery, Frozen,Detergents_Paper,Delicassen,Channel1,Channel2,Region1,Region2,Region3]])[0]
#
#     return species[i]
#
# interfaz = gr.Interface(
#
#     fn=modelo,
#
#     inputs=[
#
#         gr.Slider(label='Fresk', minimum=0.0, maximum=8.0, step=0.1),
#
#         gr.Slider(label='Milk', minimum=0.0, maximum=8.0, step=0.1),
#
#         gr.Slider(label='Grocery', minimum=0.0, maximum=8.0, step=0.1),
#
#         gr.Slider(label='Frozen', minimum=0.0, maximum=8.0, step=0.1),
#
#         gr.Slider(label='Detergents_Paper', minimum=0.0, maximum=8.0, step=0.1),
#
#         gr.Slider(label='Delicassen', minimum=0.0, maximum=8.0, step=0.1),
#
#         gr.Slider(label='Channel1', minimum=0.0, maximum=8.0, step=0.1),
#
#         gr.Slider(label='Channel2', minimum=0.0, maximum=8.0, step=0.1),
#
#         gr.Slider(label='Region1', minimum=0.0, maximum=8.0, step=0.1),
#
#         gr.Slider(label='Region2', minimum=0.0, maximum=8.0, step=0.1),
#
#         gr.Slider(label='Region3', minimum=0.0, maximum=8.0, step=0.1),
#
#     ],
#
#     outputs=gr.Textbox(label='Kmeans Grupo:'),
#
#     title='Ventas de productos',
#
#     description='Este modelo está desarrollado para la agrupacion Kmeans de productos.',
#
#     article='Antonio Fernandez Salcedo, Practicas Saturdays.AI. Aplicación desarrollada con fines docentes',
#
#     theme='peach'
#
# )
#
# interfaz.launch()
#
# C:\Users\afs28\anaconda3\Lib\site-packages\gradio\blocks.py:608: UserWarning: Cannot load peach.
#
# Caught Exception: The space peach does not exist
#
#   warnings.warn(f"Cannot load {theme}. Caught Exception: {str(e)}")
#
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
#
#
# Vamos probando como variando las entradas, obtenemos la salida del del Grupo 0, 1, 2 ó 3 (Los 4 grupos que hemos creado) en el modelo K-means con 4 clusteres.
#
# Se ha utilizado Collaboratory para crear el modelo y entrenarlo posteriormente se ha instalado gradio y podemos ver directamente la consola con la demostración del modelo que hemos creamos, también tenemos la opción de verlo en un navegador. Podemos ver diferentes resultados:
#
# ![image.png](data:image/png;base64,...)
